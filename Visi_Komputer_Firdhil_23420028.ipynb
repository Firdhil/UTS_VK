# %% [markdown]
# <a href="https://colab.research.google.com/github/Firdhil/UTS_VK/blob/main/Visi_Komputer_Firdhil_23420028.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
import numpy as np 
from google.colab.patches import cv2_imshow

# %%
image1 = cv2.imread('parkir.jpg')

# %%
img = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)

# %%
ret, thresh1 = cv2.threshold(img, 50, 820, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(img, 50, 820, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(img, 50, 820, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(img, 50, 820, cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(img, 50, 820, cv2.THRESH_TOZERO_INV)

# %%
cv2_imshow(image1)
cv2_imshow(thresh1)
cv2_imshow(thresh2)
cv2_imshow(thresh3)
cv2_imshow(thresh4)
cv2_imshow(thresh5)
# Out:
# <PIL.Image.Image image mode=RGB size=320x320 at 0x7FE3F566A5C0>
# <PIL.Image.Image image mode=L size=320x320 at 0x7FE3C6BAF5E0>
# <PIL.Image.Image image mode=L size=320x320 at 0x7FE3C6BAF8B0>
# <PIL.Image.Image image mode=L size=320x320 at 0x7FE3C6BAF5E0>
# <PIL.Image.Image image mode=L size=320x320 at 0x7FE3C6BAF8B0>
# <PIL.Image.Image image mode=L size=320x320 at 0x7FE3C6BAF5E0>
